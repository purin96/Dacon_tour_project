# %%
import missingno as msno
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.rcParams['figure.dpi'] = 300

# %%
df = pd.read_csv('../data/1.csv')

# 데이터 샘플 확인
df.head()
# Out:
#     Age  CityTier  DurationOfPitch  Occupation  NumberOfFollowups  \
# 0  41.0         3              6.0         2.0                3.0
# 1  49.0         1             14.0         2.0                4.0
# 2  37.0         1              8.0         0.0                4.0
# 3  33.0         1              9.0         2.0                3.0
# 4  38.0         1              8.0         3.0                3.0
#
#    ProductPitched  PreferredPropertyStar  MaritalStatus  Passport  \
# 0             1.0                    3.0            2.0         1
# 1             1.0                    4.0            0.0         0
# 2             0.0                    3.0            2.0         1
# 3             0.0                    3.0            0.0         1
# 4             0.0                    4.0            0.0         0
#
#    PitchSatisfactionScore  Designation  MonthlyIncome  ProdTaken
# 0                       2          2.0        20993.0          1
# 1                       3          2.0        20130.0          0
# 2                       3          1.0        17090.0          1
# 3                       5          1.0        17909.0          0
# 4                       5          1.0        18468.0          0

# %%
df= df.drop(['Unnamed: 0'],axis=1)

# %%
df.to_csv('../data/Tourism_pre.CSV')

# %%
df.head()
# Out:
#     Age  CityTier  DurationOfPitch  Occupation  NumberOfFollowups  \
# 0  41.0         3              6.0         2.0                3.0
# 1  49.0         1             14.0         2.0                4.0
# 2  37.0         1              8.0         0.0                4.0
# 3  33.0         1              9.0         2.0                3.0
# 4  38.0         1              8.0         3.0                3.0
#
#    ProductPitched  PreferredPropertyStar  MaritalStatus  Passport  \
# 0             1.0                    3.0            2.0         1
# 1             1.0                    4.0            0.0         0
# 2             0.0                    3.0            2.0         1
# 3             0.0                    3.0            0.0         1
# 4             0.0                    4.0            0.0         0
#
#    PitchSatisfactionScore  Designation  MonthlyIncome  ProdTaken
# 0                       2          2.0        20993.0          1
# 1                       3          2.0        20130.0          0
# 2                       3          1.0        17090.0          1
# 3                       5          1.0        17909.0          0
# 4                       5          1.0        18468.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4664 non-null   float64
#  1   CityTier                4888 non-null   int64
#  2   DurationOfPitch         4637 non-null   float64
#  3   Occupation              4863 non-null   float64
#  4   NumberOfFollowups       4843 non-null   float64
#  5   ProductPitched          4863 non-null   float64
#  6   PreferredPropertyStar   4862 non-null   float64
#  7   MaritalStatus           4863 non-null   float64
#  8   Passport                4888 non-null   int64
#  9   PitchSatisfactionScore  4888 non-null   int64
#  10  Designation             4863 non-null   float64
#  11  MonthlyIncome           4655 non-null   float64
#  12  ProdTaken               4888 non-null   int64
# dtypes: float64(9), int64(4)
# memory usage: 496.6 KB

# %%
import missingno as msno
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.rcParams['figure.dpi'] = 300

# %%
df.isnull().sum()
# Out:
# Age                       0
# CityTier                  0
# DurationOfPitch           0
# Occupation                0
# NumberOfFollowups         0
# ProductPitched            0
# PreferredPropertyStar     0
# MaritalStatus             0
# Passport                  0
# PitchSatisfactionScore    0
# Designation               0
# MonthlyIncome             0
# ProdTaken                 0
# dtype: int64

# %%
df = df.fillna(df.mean())

# %%
df.to_csv('../data/2.csv')

# %%
df = pd.read_csv('../data/2.csv')

# %%
df.head()
# Out:
#     Age  CityTier  DurationOfPitch  Occupation  NumberOfFollowups  \
# 0  41.0         3              6.0         2.0                3.0
# 1  49.0         1             14.0         2.0                4.0
# 2  37.0         1              8.0         0.0                4.0
# 3  33.0         1              9.0         2.0                3.0
# 4  38.0         1              8.0         3.0                3.0
#
#    ProductPitched  PreferredPropertyStar  MaritalStatus  Passport  \
# 0             1.0                    3.0            2.0         1
# 1             1.0                    4.0            0.0         0
# 2             0.0                    3.0            2.0         1
# 3             0.0                    3.0            0.0         1
# 4             0.0                    4.0            0.0         0
#
#    PitchSatisfactionScore  Designation  MonthlyIncome  ProdTaken
# 0                       2          2.0        20993.0          1
# 1                       3          2.0        20130.0          0
# 2                       3          1.0        17090.0          1
# 3                       5          1.0        17909.0          0
# 4                       5          1.0        18468.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4888 entries, 0 to 4887
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4888 non-null   float64
#  1   CityTier                4888 non-null   int64
#  2   DurationOfPitch         4888 non-null   float64
#  3   Occupation              4888 non-null   float64
#  4   NumberOfFollowups       4888 non-null   float64
#  5   ProductPitched          4888 non-null   float64
#  6   PreferredPropertyStar   4888 non-null   float64
#  7   MaritalStatus           4888 non-null   float64
#  8   Passport                4888 non-null   int64
#  9   PitchSatisfactionScore  4888 non-null   int64
#  10  Designation             4888 non-null   float64
#  11  MonthlyIncome           4888 non-null   float64
#  12  ProdTaken               4888 non-null   int64
# dtypes: float64(9), int64(4)
# memory usage: 534.6 KB

# %%
df.value_counts()
# Out:
# Age   CityTier  DurationOfPitch  Occupation  NumberOfFollowups  ProductPitched  PreferredPropertyStar  MaritalStatus  Passport  PitchSatisfactionScore  Designation  MonthlyIncome  ProdTaken
# 37.0  1         15.0             3.0         4.0                3.0             3.0                    3.0            0         4                       3.0          28774.0        0            2
# 28.0  1         9.0              2.0         4.0                1.0             5.0                    3.0            0         3                       2.0          21019.0        0            2
# 50.0  1         15.0             2.0         4.0                3.0             4.0                    1.0            0         4                       3.0          26081.0        0            2
# 39.0  1         17.0             2.0         4.0                1.0             3.0                    3.0            0         5                       2.0          21362.0        0            2
#                                  1.0         4.0                0.0             3.0                    3.0            0         3                       1.0          28502.0        0            2
#                                                                                                                                                                                                 ..
# 33.0  3         28.0             2.0         3.0                1.0             4.0                    1.0            0         1                       2.0          21146.0        0            1
#                                  3.0         3.0                1.0             4.0                    0.0            0         2                       2.0          21146.0        0            1
#                 31.0             1.0         4.0                0.0             4.0                    2.0            1         5                       1.0          23380.0        1            1
#                 33.0             3.0         4.0                1.0             3.0                    0.0            0         4                       2.0          23143.0        0            1
# 61.0  3         35.0             2.0         5.0                1.0             5.0                    1.0            0         1                       2.0          28944.0        0            1
# Length: 4579, dtype: int64

# %%
msno.matrix(df)
plt.show()
